# %%
import os
os.chdir(r"C:\Users\JAYANTH R\OneDrive\Desktop\rice_project")

# %% [markdown]
# count images per class:

# %%
dataset_path = r"dataset\raw_images"

for category in os.listdir(dataset_path):
    category_path = os.path.join(dataset_path, category)
    print(category, ":", len(os.listdir(category_path)))
# Out:
# Arborio : 14990
# Basmati : 15000
# Ipsala : 15000
# Jasmine : 15000
# Karacadag : 15000

# %% [markdown]
# Visualize sample image:

# %%
import matplotlib.pyplot as plt
from PIL import Image
import random

def show_sample_images(category):
    category_path = os.path.join(dataset_path, category)
    images = os.listdir(category_path)
    
    plt.figure(figsize=(10,5))
    
    for i in range(5):
        img = Image.open(os.path.join(category_path, random.choice(images)))
        plt.subplot(1,5,i+1)
        plt.imshow(img)
        plt.axis("off")
    
    plt.show()

show_sample_images("Basmati")

# %% [markdown]
# check image size:

# %%
from PIL import Image

for category in os.listdir(dataset_path):
    category_path = os.path.join(dataset_path, category)
    sample_image = os.listdir(category_path)[0]
    
    img = Image.open(os.path.join(category_path, sample_image))
    print(f"{category} image size: {img.size}")
# Out:
# Arborio image size: (250, 250)
# Basmati image size: (250, 250)
# Ipsala image size: (250, 250)
# Jasmine image size: (250, 250)
# Karacadag image size: (250, 250)

# %% [markdown]
# check corrupted images:

# %%
from PIL import Image
import os

for category in os.listdir(dataset_path):
    category_path = os.path.join(dataset_path, category)
    
    for img_name in os.listdir(category_path):
        try:
            img = Image.open(os.path.join(category_path, img_name))
            img.verify()
        except:
            print(f"Corrupted image found: {img_name}")

# %% [markdown]
# check class distribution graph:

# %%
import matplotlib.pyplot as plt

categories = []
counts = []

for category in os.listdir(dataset_path):
    category_path = os.path.join(dataset_path, category)
    if os.path.isdir(category_path):
        categories.append(category)
        counts.append(len(os.listdir(category_path)))

plt.bar(categories, counts)
plt.title("Class Distribution")
plt.xlabel("Rice Variety")
plt.ylabel("Number of Images")
plt.xticks(rotation=45)
plt.show()
